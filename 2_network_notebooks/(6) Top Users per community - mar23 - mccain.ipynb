# %%
import pandas as pd
import numpy as np

import pickle

# %% [markdown]
# Here I am going to find the top accounts per community, and look at some tweets

# %%
with open('/Users/robertpagano/src/metis_project_kojak/network_files/mccain/community_pickles_pre_nlp/df_0.pickle', 'rb') as f:
    df_com_0 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/mccain/community_pickles_pre_nlp/df_1.pickle', 'rb') as f:
    df_com_1 = pickle.load(f)
        
with open('/Users/robertpagano/src/metis_project_kojak/network_files/mccain/community_pickles_pre_nlp/df_3.pickle', 'rb') as f:
    df_com_3 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/mccain/community_pickles_pre_nlp/df_4.pickle', 'rb') as f:
    df_com_4 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/mccain/community_pickles_pre_nlp/df_5.pickle', 'rb') as f:
    df_com_5 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/mccain/community_pickles_pre_nlp/df_6.pickle', 'rb') as f:
    df_com_6 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/mccain/community_pickles_pre_nlp/df_7.pickle', 'rb') as f:
    df_com_7 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/mccain/community_pickles_pre_nlp/df_8.pickle', 'rb') as f:
    df_com_8 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/mccain/community_pickles_pre_nlp/df_9.pickle', 'rb') as f:
    df_com_9 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/mccain/community_pickles_pre_nlp/df_10.pickle', 'rb') as f:
    df_com_10 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/mccain/community_pickles_pre_nlp/df_11.pickle', 'rb') as f:
    df_com_11 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/mccain/community_pickles_pre_nlp/df_12.pickle', 'rb') as f:
    df_com_12 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/mccain/community_pickles_pre_nlp/df_13.pickle', 'rb') as f:
    df_com_13 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/mccain/community_pickles_pre_nlp/df_14.pickle', 'rb') as f:
    df_com_14 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/mccain/community_pickles_pre_nlp/df_15.pickle', 'rb') as f:
    df_com_15 = pickle.load(f)

# %%
df_com_0_top_20 = df_com_0.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_1_top_20 = df_com_1.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_3_top_20 = df_com_3.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_4_top_20 = df_com_4.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_5_top_20 = df_com_5.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_6_top_20 = df_com_6.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_7_top_20 = df_com_7.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_8_top_20 = df_com_8.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_9_top_20 = df_com_9.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_10_top_20 = df_com_10.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_11_top_20 = df_com_11.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_12_top_20 = df_com_12.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_13_top_20 = df_com_13.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_14_top_20 = df_com_14.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_15_top_20 = df_com_15.drop_duplicates(subset='screen_name', keep='first').head(20)

# %%
## Resistance - left PRO MCCAIN

df_com_0_top_20.head(10)
# Out:
#             screen_name  followers_count  modularity_class  \
# 380860           funder           450281               0.0
# 823227        EdKrassen           900756               0.0
# 536014     krassenstein           666380               0.0
# 570454     PalmerReport           243036               0.0
# 718606       ananavarro          1129725               0.0
# 373317       mmpadellan           223084               0.0
# 972511       Goss30Goss            76771               0.0
# 42375       travisakers            78131               0.0
# 313898  realDonaldTrFan           237850               0.0
# 179447       TeaPainUSA           437215               0.0
#
#                                                 main_text  \
# 380860  RT @funder: 46 years ago Senator John McCain s...
# 823227  John McCain is an American hero.\n\nIt's despi...
# 536014  Trump: "I gave [John McCain] the kind of funer...
# 570454  George Conway: Trump is mentally deranged.\n\n...
# ...

# %%
## Establishment media centrists, PRO MCCAIN

df_com_1_top_20.head(10)
# Out:
#            screen_name  followers_count  modularity_class  \
# 749368          Acosta          1218658               1.0
# 554500  kurteichenwald           460186               1.0
# 642551      SenSchumer          1730995               1.0
# 775682    amyklobuchar           658156               1.0
# 735792   TheRickWilson           496752               1.0
# 369233     BillKristol           457393               1.0
# 754389          JoeNBC          2537438               1.0
# 545327   soledadobrien           957209               1.0
# 915581      gtconway3d           466263               1.0
# 875387    Peter_Wehner            41728               1.0
#
#                                                 main_text  \
# 749368  A former McCain aide says Trump was lying when...
# 554500  John McCain: tortured as a POW, but when offer...
# 642551  I look forward to soon re-introducing my legis...
# 775682  This Vietnam vet was brought to tears when hea...
# ...

# %%
## Very similar to 2 PRO
df_com_3_top_20.head(10)
# Out:
#             screen_name  followers_count  modularity_class  \
# 469792         votevets           158253               3.0
# 598899     DavidJollyFL            85154               3.0
# 595738  ShuttleCDRKelly           274965               3.0
# 498696    SenatorBennet           285101               3.0
# 565963         timkaine           990715               3.0
# 596182    shannonrwatts           299631               3.0
# 260918  StevenBeschloss            51082               3.0
# 548735        adamcbest           143591               3.0
# 633123        JohnKerry          3341782               3.0
# 757184    Allen_Clifton            19383               3.0
#
#                                                 main_text  \
# 469792  RT @PeteButtigieg: When a president (who faked...
# 598899  Your move, every GOP Senator.\n\nYou served wi...
# 595738  Senator McCain nearly gave his life fighting f...
# 498696  John McCain was a man of honor, integrity, con...
# ...

# %%
## News accounts, PRO MCCAIN
df_com_4_top_20.head(10)
# Out:
#            screen_name  followers_count  modularity_class  \
# 885088         TheView           747264               4.0
# 830209             ABC         14207847               4.0
# 308001             CNN         41574387               4.0
# 890565     ABCPolitics           725748               4.0
# 456705           MSNBC          2360623               4.0
# 300090         thehill          3222375               4.0
# 600006         NBCNews          6460061               4.0
# 435194  washingtonpost         13500944               4.0
# 734434     CNNPolitics          2765024               4.0
# 882836        politico          3781807               4.0
#
#                                                 main_text  \
# 885088  .@MeghanMcCain responds to Pres. Trump’s attac...
# 830209  .@MeghanMcCain responds to President Trump's a...
# 308001  “I don’t like it,” former White House communic...
# 890565  RT @TheView: .@MeghanMcCain addresses Pres. Tr...
# ...

# %%
## leftists, activists ANTI MCCAIN

df_com_5_top_20.head(10)
# Out:
#          screen_name  followers_count  modularity_class  \
# 600646     bubbaprog            54064               5.0
# 599619     desusnice           906337               5.0
# 171064      TheOnion         11077671               5.0
# 598706  mattyglesias           422281               5.0
# 294340    MikeGravel            29741               5.0
# 893968   SeanMcElwee            91924               5.0
# 587850  david_j_roth            76241               5.0
# 735551  UrbanAchievr            19225               5.0
# 632893        swin24            61280               5.0
# 596714  crushingbort            66531               5.0
#
#                                                 main_text  \
# 600646  Trump complains that John McCain did not come ...
# 599619  Tempted to make a ghost of John McCain twitter...
# 171064  Trump Ramps Up Attacks On John McCain By Dragg...
# 598706  I’ve got to say, before asking Trump yet anoth...
# ...

# %%
## mix of lefty pro and anti

df_com_6_top_20.head(10)
# Out:
#            screen_name  followers_count  modularity_class  \
# 557843   PeteButtigieg           431603               6.0
# 1010620      TVietor08           417408               6.0
# 591638        rollcall           358829               6.0
# 557322       justdawn_             2847               6.0
# 283538        Pschlarm             2806               6.0
# 473658     Hollander66               99               6.0
# 237184   splinter_news           571728               6.0
# 481983       Tired2Iam             4661               6.0
# 178659    migo64587452              305               6.0
# 499819      ami_tvdfan             2203               6.0
#
#                                                  main_text  \
# 557843   When a president (who faked a disability in or...
# 1010620  Just the President of the United States retwee...
# 591638   "It’s deplorable,” Sen. Johnny Isakson says of...
# 557322   @TIME Dear Senate &amp; House Republicans,\nYo...
# ...

# %%
## media and celebs left PRO MCCAIN

df_com_7_top_20.head(10)
# Out:
#             screen_name  followers_count  modularity_class  \
# 799747        billmaher         11020646               7.0
# 720080            AC360          1282805               7.0
# 757946        DanRather           633443               7.0
# 397441      GeorgeTakei          2854322               7.0
# 712107       CNNTonight            83010               7.0
# 474275   ABFalecbaldwin          1106135               7.0
# 599148    HardballChris           904600               7.0
# 60513   FrankTheDoorman            35722               7.0
# 706332        ejmontini             8278               7.0
# 616020      MADmagazine            56725               7.0
#
#                                                 main_text  \
# 799747  Is there anything more unseemly than Trump con...
# 720080  “I don’t care if you like John McCain or could...
# 757946  Seeing President Trump haunted by John McCain ...
# 397441  I want John McCain to come back to haunt the c...
# ...

# %%
## Republicans PRO MCCAIN, criticizing trump

df_com_8_top_20.head(10)
# Out:
#             screen_name  followers_count  modularity_class  \
# 184474   RepDanCrenshaw           251565               8.0
# 755169       MittRomney          1983078               8.0
# 183463    DanCrenshawTX           371799               8.0
# 613135     SenMcSallyAZ            57830               8.0
# 1033505      EWErickson           208130               8.0
# 623252     senatemajldr           837628               8.0
# 17147          brithume           996715               8.0
# 723245        HeathMayo            20274               8.0
# 868544        JReinerMD             4604               8.0
# 171823      Zigmanfreud            36878               8.0
#
#                                                  main_text  \
# 184474   Mr. President, seriously stop talking about Se...
# 755169   I can’t understand why the President would, on...
# 183463   There is just no reason to be talking about Se...
# 613135   John McCain is an American hero and I am thank...
# ...

# %%
## Trump cultists, ANTI MCCAIN

df_com_9_top_20.head(10)
# Out:
#            screen_name  followers_count  modularity_class  \
# 846664     mitchellvii           411403               9.0
# 878734  RealJamesWoods          2063087               9.0
# 310466   charliekirk11           985947               9.0
# 583520    chuckwoolery           524069               9.0
# 567623     almostjingo            59233               9.0
# 285180        catturd2            35675               9.0
# 218891    JackPosobiec           438870               9.0
# 268432          C_3C_3            50781               9.0
# 233252   RealMattCouch           158594               9.0
# 259327  PoliticalShort           156469               9.0
#
#                                                 main_text  \
# 846664  I'm sorry, but John McCain was not a great man...
# 878734  “In a newly unsealed declaration from Septembe...
# 310466  When McCain ran for President the media attack...
# 583520  Like every Conservative, I never trusted John ...
# ...

# %%
## Conservatives moderates Pro MCCAIN

df_com_10_top_20.head(10)
# Out:
#             screen_name  followers_count  modularity_class  \
# 765996       JohnKasich           948511              10.0
# 578594        JeffFlake           663817              10.0
# 910485   DadoftheDecade             7527              10.0
# 456034       RepSlotkin            11737              10.0
# 576312      Redpainter1            47381              10.0
# 429931        tackettdc            23839              10.0
# 555549  ArshiaHomayoun2              122              10.0
# 511898    ChristianDems            19083              10.0
# 368996     ElkeMarriott              449              10.0
# 541203    PKanagaratnam              781              10.0
#
#                                                 main_text  \
# 765996  I was always a fan of @SenJohnMcCain and I alw...
# 578594  I was pleased to co-sponsor this resolution la...
# 910485  Since the New Zealand shooting, @realdonaldtru...
# 456034  The President’s continued disparaging remarks ...
# ...

# %%
## neutral media PRO MCCAIN

df_com_11_top_20.head(10)
# Out:
#             screen_name  followers_count  modularity_class  \
# 597270            cspan          1939244              11.0
# 811709  amandacarpenter           129038              11.0
# 584867   Philip_Elliott            30582              11.0
# 557635     davidjoachim            15062              11.0
# 534997   TwitterMoments           661580              11.0
# 802744      markknoller           321673              11.0
# 816449   WhatSteveSays_               15              11.0
# 802435     dave_brown24             6337              11.0
# 765356        sppeoples            17128              11.0
# 803729  rebeccaballhaus            63544              11.0
#
#                                                 main_text retweet_text  \
# 597270  President Trump on John McCain: "I gave him th...          NaN
# 811709  Trump makes Republicans choose him or their pr...          NaN
# 584867  The President was in Ohio to promote his effor...          NaN
# ...

# %%
## pro mccain dems

df_com_12_top_20.head(10)
# Out:
#             screen_name  followers_count  modularity_class  \
# 482271          RBReich           661995              12.0
# 583390  thegoodgodabove           440376              12.0
# 483597    BernieSanders          9155566              12.0
# 796723    OpenSecretsDC           126494              12.0
# 200168      TitusNation           125353              12.0
# 364853  jenniferscully1             8429              12.0
# 769953         pdacosta           126688              12.0
# 820833   MagdaSzubanski           111022              12.0
# 518658      petercoffin            28592              12.0
# 83694   nashville_brook             1987              12.0
#
#                                                 main_text  \
# 482271  With every petty attack on John McCain, Trump ...
# 583390  Hey Republicans,\n\nI see you today are writin...
# 483597  Sen. John McCain was a friend and a man of gre...
# 796723  Donald Trump contributed to John McCain multip...
# ...

# %%
## resistance libs PRO MCCAIN

df_com_13_top_20.head(10)
# Out:
#             screen_name  followers_count  modularity_class  \
# 578062     MrFilmkritik            69964              13.0
# 509456  goldengateblond           289349              13.0
# 576790        Robillard            19423              13.0
# 504616  itsJeffTiedrich           102794              13.0
# 455399   WestWingReport           379759              13.0
# 499621  AkilahObviously           145030              13.0
# 361593          evanier             6877              13.0
# 592541     TheSpoonyOne            38403              13.0
# 552389      tiffanyclay             3805              13.0
# 527956    the_blueprint            15735              13.0
#
#                                                 main_text  \
# 578062  Republicans: "Colin Kaepernick is so disrespec...
# 509456  The takeaway of his beef with John McCain is T...
# 576790  Trump, today: “I never was a fan of John McCai...
# 504616  wouldn't it be nice if the poltroon who was to...
# ...

# %%
## comedians against trump PRO MCCAIN

df_com_14_top_20.head(10)
# Out:
#             screen_name  followers_count  modularity_class  \
# 596514     AlbertBrooks          1744962              14.0
# 587931     TheDailyShow          7838504              14.0
# 369459  realjeffreyross           891072              14.0
# 460581      TheAtlantic          1768670              14.0
# 465034    PeterAtlantic            10806              14.0
# 992527        canyonjim            86218              14.0
# 879026  imjustinrandall             5706              14.0
# 386122     juliussharpe           160163              14.0
# 591700    margarettalev            41541              14.0
# 520122      misst070171              249              14.0
#
#                                                 main_text  \
# 596514  Listening to Trump continuing to trash John Mc...
# 587931  "I, Donald J. Trump, am calling on Senator Joh...
# 369459  If the President had actually planned Senator ...
# 460581  RT @PeterAtlantic: Arnold Schwarzenegger calls...
# ...

# %%
## resistance PRO MCCAIN

df_com_15_top_20.head(10)
# Out:
#              screen_name  followers_count  modularity_class  \
# 182567    PeterAlexander           295954              15.0
# 54428         WajahatAli           116490              15.0
# 1001033          atrupar            88255              15.0
# 101368      DrRJKavanagh            33121              15.0
# 543749       mehdirhasan           599106              15.0
# 872457           owillis           122910              15.0
# 569335            LOLGOP           358587              15.0
# 152818   Freddie24495909              563              15.0
# 629388    Celeste_pewter            22888              15.0
# 715449           digby56            47660              15.0
#
#                                                  main_text  \
# 182567   Trump, yesterday: "I gave [Sen. McCain] the ki...
# 54428    RT @kurteichenwald: the trump cult is loaded w...
# 1001033  The account Trump retweeted (@Lrihendry) to in...
# 101368   Just a reminder, it's exactly a week to the ho...
# ...
