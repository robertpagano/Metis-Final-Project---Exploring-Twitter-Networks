# %%
# %config InlineBackend.figure_format = 'svg'

import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
import tweepy, sys, os, logging, json

import pandas as pd
import numpy as np

import pickle

from tweet_clean import deefify2

# %%
pd.set_option('display.max_columns', 500)

# %%
with open('/Users/robertpagano/metis_data/project_5/final_raw_marvel_df.pickle', 'rb') as f:
    df_all_marvel = pickle.load(f)

# %%
df_all_marvel['is_retweet'].sum()
# Out:
# 1155778

# %%
df_all_marvel['retweet_screen_name'].nunique()
# Out:
# 47799

# %% [markdown]
# So, there are 1155778 TOTAL retweets, and of those, there are 47799 people being retweeted! This means that on average, the people being retweeted are being retweeted 24 times (and I imagine the distribution is skewed)
#
# Here is how I can include a graph that shows how influence works, i.e. theres 1.77 million unique people in my list, but on 48k are retweeted, and here's the distribution of those to show how the influence is even MORE skewed

# %%
1155778/47799
# Out:
# 24.17996192388962

# %%
top_20_retweeted = df_all_marvel.groupby(['retweet_screen_name'])[['is_retweet']].sum().reset_index().nlargest(20, 'is_retweet')
top_50_retweeted = df_all_marvel.groupby(['retweet_screen_name'])[['is_retweet']].sum().reset_index().nlargest(50, 'is_retweet')


# .nlargest(20)

# %%
top_20_retweeted
# Out:
#       retweet_screen_name  is_retweet
# 16131       OriginalFunko       86368
# 13794       MarvelStudios       41714
# 27792       captainmarvel       40677
# 23268                Xbox       22783
# 27307          brielarson       22368
# 32452            gwilymst       21604
# 22386            UpToTASK       19922
# 6318        Drachearannak       17564
# 30568         eleanorbate       15362
# 13769              Marvel       15152
# 4303           ChrisEvans       15025
# 29138          cyanwhisky       13791
# 6809         EmilHofilena       10191
# 13168          MCU_Direct        9658
# 32787          hemsthorth        9521
# 395                  9GAG        9082
# 7242             Fandango        7931
# 37615          malihaness        7436
# 9271                  IGN        7062
# 20782      ThatKevinSmith        7014

# %%
import seaborn as sns

# %%
labels_top_20 = top_20_retweeted['retweet_screen_name'].unique()
labels_top_20

labels_top_50 = top_50_retweeted['retweet_screen_name'].unique()
labels_top_50
# Out:
# array(['OriginalFunko', 'MarvelStudios', 'captainmarvel', 'Xbox',
#        'brielarson', 'gwilymst', 'UpToTASK', 'Drachearannak',
#        'eleanorbate', 'Marvel', 'ChrisEvans', 'cyanwhisky',
#        'EmilHofilena', 'MCU_Direct', 'hemsthorth', '9GAG', 'Fandango',
#        'malihaness', 'IGN', 'ThatKevinSmith', 'CaptMarvelNews',
#        'TomTaylorMade', 'scarfff', 'THR', 'starwarspoe', 'MarkRuffalo',
#        'ManaByte', 'NetflixUK', 'JacobTremblay', 'BBW_BFF', 'capmadden',
#        'nicomiinoru', 'getFANDOM', 'AdamPenale', 'doryheartsbooks',
#        'jillboard', 'mitchkbay', 'Lupita_Nyongo', 'ComicBookNOW',
#        'peterquillsI', 'CAPTAlNERD', 'lizzieolses', 'BNKGSH', 'mcucevans',
#        'hulknaps', 'iamgeekingout', 'MingjueChen', 'DemetriusHarmon',
#        'OhNoSheTwitnt', 'renfamous'], dtype=object)

# %%
top_20_bar = sns.barplot(x = top_20_retweeted['retweet_screen_name'], y=top_20_retweeted['is_retweet'])

top_20_bar.set(xlabel='Screen Name', ylabel='# of times retweeted')
top_20_bar.set_xticklabels(labels = labels_top_20, rotation=90);

# %% [markdown]
# I'll come back to fix this, but even now, you can see that the influence is clear for some accounts

# %%
top_50_retweeted
# Out:
#       retweet_screen_name  is_retweet
# 16131       OriginalFunko       86368
# 13794       MarvelStudios       41714
# 27792       captainmarvel       40677
# 23268                Xbox       22783
# 27307          brielarson       22368
# 32452            gwilymst       21604
# 22386            UpToTASK       19922
# 6318        Drachearannak       17564
# 30568         eleanorbate       15362
# 13769              Marvel       15152
# 4303           ChrisEvans       15025
# 29138          cyanwhisky       13791
# 6809         EmilHofilena       10191
# 13168          MCU_Direct        9658
# 32787          hemsthorth        9521
# 395                  9GAG        9082
# 7242             Fandango        7931
# 37615          malihaness        7436
# 9271                  IGN        7062
# 20782      ThatKevinSmith        7014
# 3808       CaptMarvelNews        6852
# 21845       TomTaylorMade        6386
# 42698             scarfff        6241
# 20332                 THR        6091
# 44038         starwarspoe        5964
# 13695         MarkRuffalo        5784
# 13535            ManaByte        5731
# 15444           NetflixUK        5544
# 10184       JacobTremblay        5243
# 2082              BBW_BFF        5175
# 27757           capmadden        5047
# 39671         nicomiinoru        4973
# 32013           getFANDOM        4861
# 803            AdamPenale        4790
# 30150     doryheartsbooks        4528
# 34747           jillboard        4415
# 38695           mitchkbay        4235
# 13063       Lupita_Nyongo        3736
# 4678         ComicBookNOW        3732
# 40735        peterquillsI        3719
# 3431           CAPTAlNERD        3679
# 37026         lizzieolses        3672
# 2163               BNKGSH        3616
# 38139           mcucevans        3594
# 33131            hulknaps        3568
# 33333       iamgeekingout        3488
# 14432         MingjueChen        3301
# 5837      DemetriusHarmon        3216
# 15996       OhNoSheTwitnt        3115
# 41734           renfamous        3109

# %%
top_50_bar = sns.barplot(x = top_50_retweeted['retweet_screen_name'], y=top_50_retweeted['is_retweet'])


top_50_bar.set(xlabel='Screen Name', ylabel='# of times retweeted')
top_50_bar.set_xticklabels(labels = labels_top_50, rotation=90);

# %%
df_all_marvel.head()
# Out:
#               tweet_id             user_id  display_name   screen_name  \
# 0  1107088444658978816           442928354  Erica Miller  EricaFMiller
# 1  1107088442356367360           408092583  Annie Rachel     Annferddd
# 2  1107088441588830209  902039904099684352       𝙠𝙮𝙧𝙖  ♡       cptkyra
# 3  1107088439382429696  985172108547309569           레돌샨     chisakaoo
# 4  1107088438703128576          2864913304   dirty diana     dollyweep
#
#                        tweet_date  \
# 0  Sun Mar 17 01:17:08 +0000 2019
# 1  Sun Mar 17 01:17:08 +0000 2019
# 2  Sun Mar 17 01:17:07 +0000 2019
# 3  Sun Mar 17 01:17:07 +0000 2019
# 4  Sun Mar 17 01:17:07 +0000 2019
#
#                                            main_text  fav_count  rt_count  \
# 0  RT @Raulc_52: Intro to Captain Marvel\nMe: htt...          0         5
# 1  RT @gwilymst: captain marvel without context  ...          0     32858
# 2  RT @lalisamcu: the gays when the scene cut to ...          0        26
# 3  RT @cyanwhisky: #AvengersEndgame #CaptainMarve...          0     13712
# 4  RT @gwilymst: captain marvel without context  ...          0     32858
#
#    followers_count  is_verified  reply_to_tweet_id  reply_to_user_id  \
# 0              128        False                NaN               NaN
# 1              411        False                NaN               NaN
# 2              147        False                NaN               NaN
# 3               60        False                NaN               NaN
# 4              141        False                NaN               NaN
#
#   reply_to_screen_name                                       retweet_text  \
# 0                 None  Intro to Captain Marvel\nMe: https://t.co/WMJT...
# 1                 None  captain marvel without context  https://t.co/F...
# 2                 None  the gays when the scene cut to brie larson rid...
# 3                 None  #AvengersEndgame #CaptainMarvel OK I'm ready f...
# 4                 None  captain marvel without context  https://t.co/F...
#
#      retweet_id  retweet_user_id retweet_screen_name retweet_is_verified  \
# 0  1.107028e+18     2.344318e+09            Raulc_52               False
# 1  1.106192e+18     1.042657e+18            gwilymst               False
# 2  1.105913e+18     9.735315e+17           lalisamcu               False
# 3  1.106903e+18     1.966503e+08          cyanwhisky               False
# 4  1.106192e+18     1.042657e+18            gwilymst               False
#
#    retweet_fav_count  retweet_followers_count quoted_text  quoted_id  \
# 0               13.0                    407.0         NaN        NaN
# 1            70766.0                    368.0         NaN        NaN
# 2               97.0                    112.0         NaN        NaN
# 3            31450.0                  26699.0         NaN        NaN
# 4            70766.0                    368.0         NaN        NaN
#
#    quoted_user_id quoted_screen_name quoted_is_verified  quoted_fav_count  \
# 0             NaN                NaN                NaN               NaN
# 1             NaN                NaN                NaN               NaN
# 2             NaN                NaN                NaN               NaN
# 3             NaN                NaN                NaN               NaN
# 4             NaN                NaN                NaN               NaN
#
#    is_retweet  is_quote
# 0           1         0
# 1           1         0
# 2           1         0
# 3           1         0
# 4           1         0
