# %%
# %config InlineBackend.figure_format = 'svg'

import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
import tweepy, sys, os, logging, json

import pandas as pd
import numpy as np

import pickle

from tweet_clean import deefify2

# %%
pd.set_option('display.max_columns', 500)

# %%
with open('/Users/robertpagano/metis_data/project_5/final_raw_df.pickle', 'rb') as f:
    df_all_raw = pickle.load(f)

# %%
df_all_raw['is_retweet'].sum()
# Out:
# 984636

# %%
df_all_raw['retweet_screen_name'].nunique()
# Out:
# 40660

# %% [markdown]
# So, there are 984636 TOTAL retweets, and of those, there are 40660 people being retweeted! This means that on average, the people being retweeted are being retweeted 24 times (and I imagine the distribution is skewed)
#
# Here is how I can include a graph that shows how influence works, i.e. theres 1.6 million unique people in my list, but on 40k are retweeted, and here's the distribution of those to show how the influence is even MORE skewed

# %%
984636/40660
# Out:
# 24.216330545991145

# %%
top_20_retweeted = df_all_raw.groupby(['retweet_screen_name'])[['is_retweet']].sum().reset_index().nlargest(20, 'is_retweet')
top_50_retweeted = df_all_raw.groupby(['retweet_screen_name'])[['is_retweet']].sum().reset_index().nlargest(50, 'is_retweet')


# .nlargest(20)

# %%
top_20_retweeted
# Out:
#       retweet_screen_name  is_retweet
# 26237       charliekirk11       59243
# 17699        RealSaavedra       40704
# 741                   AOC       27569
# 17663      RealJamesWoods       18771
# 27342            dbongino       18746
# 8342      GovMikeHuckabee       15342
# 23767       _waleedshahid       12480
# 5587       DavidJHarrisJr       12409
# 770         ARmastrangelo       11530
# 28587         fabiochiusi       11523
# 2693              BillNye       10696
# 18677       RyanAFournier        9901
# 17631        RealCandaceO        9895
# 13791         MarkRuffalo        9648
# 25099          benshapiro        9432
# 32263        krassenstein        9147
# 9401        IngrahamAngle        8360
# 7841        GOPChairwoman        8127
# 22975     WayneDupreeShow        7714
# 17658            RealJack        7174

# %%
import seaborn as sns

# %%
labels_top_20 = top_20_retweeted['retweet_screen_name'].unique()
labels_top_20

labels_top_50 = top_50_retweeted['retweet_screen_name'].unique()
labels_top_50
# Out:
# array(['charliekirk11', 'RealSaavedra', 'AOC', 'RealJamesWoods',
#        'dbongino', 'GovMikeHuckabee', '_waleedshahid', 'DavidJHarrisJr',
#        'ARmastrangelo', 'fabiochiusi', 'BillNye', 'RyanAFournier',
#        'RealCandaceO', 'MarkRuffalo', 'benshapiro', 'krassenstein',
#        'IngrahamAngle', 'GOPChairwoman', 'WayneDupreeShow', 'RealJack',
#        'KatiePavlich', 'CraigSBPA', 'larryelder', 'EdKrassen',
#        'hrtablaze', 'mitchellvii', 'seanhannity', 'peterdaou',
#        'SuperEliteTexan', 'ChuckCallesto', 'trish_regan', 'tictoc',
#        'Liz_Wheeler', 'itsJeffTiedrich', 'catturd2', 'gaywonk',
#        'Liz_Cheney', 'thecjpearson', 'AndrewPollackFL', 'DoingRight1',
#        'marklutchman', 'paulsperry_', 'cvpayne', 'gatewaypundit',
#        'BuckSexton', 'TomiLahren', 'MarkDice', 'daveweigel', 'bud_cann',
#        'DanielTurnerPTF'], dtype=object)

# %%
top_20_bar = sns.barplot(x = top_20_retweeted['retweet_screen_name'], y=top_20_retweeted['is_retweet'])

top_20_bar.set(xlabel='Screen Name', ylabel='# of times retweeted')
top_20_bar.set_xticklabels(labels = labels_top_20, rotation=90);

# %% [markdown]
# I'll come back to fix this, but even now, you can see that the influence is clear for some accounts

# %%
top_50_retweeted
# Out:
#       retweet_screen_name  is_retweet
# 26237       charliekirk11       59243
# 17699        RealSaavedra       40704
# 741                   AOC       27569
# 17663      RealJamesWoods       18771
# 27342            dbongino       18746
# 8342      GovMikeHuckabee       15342
# 23767       _waleedshahid       12480
# 5587       DavidJHarrisJr       12409
# 770         ARmastrangelo       11530
# 28587         fabiochiusi       11523
# 2693              BillNye       10696
# 18677       RyanAFournier        9901
# 17631        RealCandaceO        9895
# 13791         MarkRuffalo        9648
# 25099          benshapiro        9432
# 32263        krassenstein        9147
# 9401        IngrahamAngle        8360
# 7841        GOPChairwoman        8127
# 22975     WayneDupreeShow        7714
# 17658            RealJack        7174
# 11623        KatiePavlich        6690
# 4824            CraigSBPA        6637
# 32472          larryelder        6325
# 6741            EdKrassen        6243
# ...

# %%
top_50_bar = sns.barplot(x = top_50_retweeted['retweet_screen_name'], y=top_50_retweeted['is_retweet'])


top_50_bar.set(xlabel='Screen Name', ylabel='# of times retweeted')
top_50_bar.set_xticklabels(labels = labels_top_50, rotation=90);
