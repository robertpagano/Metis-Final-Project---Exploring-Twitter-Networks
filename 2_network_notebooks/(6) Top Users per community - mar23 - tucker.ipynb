# %%
import pandas as pd
import numpy as np

import pickle

# %% [markdown]
# Here I am going to find the top accounts per community, and look at some tweets

# %%
with open('/Users/robertpagano/src/metis_project_kojak/network_files/tucker/community_pickles_pre_nlp/df_0.pickle', 'rb') as f:
    df_com_0 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/tucker/community_pickles_pre_nlp/df_1.pickle', 'rb') as f:
    df_com_1 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/tucker/community_pickles_pre_nlp/df_2.pickle', 'rb') as f:
    df_com_2 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/tucker/community_pickles_pre_nlp/df_3.pickle', 'rb') as f:
    df_com_3 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/tucker/community_pickles_pre_nlp/df_4.pickle', 'rb') as f:
    df_com_4 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/tucker/community_pickles_pre_nlp/df_5.pickle', 'rb') as f:
    df_com_5 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/tucker/community_pickles_pre_nlp/df_6.pickle', 'rb') as f:
    df_com_6 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/tucker/community_pickles_pre_nlp/df_7.pickle', 'rb') as f:
    df_com_7 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/tucker/community_pickles_pre_nlp/df_8.pickle', 'rb') as f:
    df_com_8 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/tucker/community_pickles_pre_nlp/df_9.pickle', 'rb') as f:
    df_com_9 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/tucker/community_pickles_pre_nlp/df_10.pickle', 'rb') as f:
    df_com_10 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/tucker/community_pickles_pre_nlp/df_11.pickle', 'rb') as f:
    df_com_11 = pickle.load(f)
    
with open('/Users/robertpagano/src/metis_project_kojak/network_files/tucker/community_pickles_pre_nlp/df_12.pickle', 'rb') as f:
    df_com_12 = pickle.load(f)

# %%
df_com_0_top_20 = df_com_0.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_1_top_20 = df_com_1.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_2_top_20 = df_com_2.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_3_top_20 = df_com_3.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_4_top_20 = df_com_4.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_5_top_20 = df_com_5.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_6_top_20 = df_com_6.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_7_top_20 = df_com_7.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_8_top_20 = df_com_8.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_9_top_20 = df_com_9.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_10_top_20 = df_com_10.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_11_top_20 = df_com_11.drop_duplicates(subset='screen_name', keep='first').head(20)
df_com_12_top_20 = df_com_12.drop_duplicates(subset='screen_name', keep='first').head(20)

# %%
## Progressive Activists ANTI

df_com_0_top_20.head(10)
# Out:
#            screen_name  followers_count  modularity_class  \
# 461002       JordanUhl           137928               0.0
# 215878    slpng_giants           227472               0.0
# 475363       JuddLegum           337543               0.0
# 460879            mmfa           388372               0.0
# 199846  ndrew_lawrence            21610               0.0
# 474014    brianstelter           632105               0.0
# 446693     womensmarch           634132               0.0
# 287149  kurteichenwald           460134               0.0
# 143429      curaffairs            66481               0.0
# 161014        TheOnion         11076463               0.0
#
#                                                 main_text  \
# 461002  RT @nowthisnews: Exclusive: Tucker Carlson's s...
# 215878  RT @JaneMayerNYer: Who Bankrolls Tucker Carlso...
# 475363  UPDATE: No statement from the company but ther...
# 460879  RT @nowthisnews: Exclusive: Tucker Carlson's s...
# ...

# %%
## Moderates, broadcasters ANTI

df_com_1_top_20.head(10)
# Out:
#            screen_name  followers_count  modularity_class  \
# 462059     nowthisnews          2244052               1.0
# 423488     ScottMcGrew             7678               1.0
# 392143     keithboykin           172327               1.0
# 406792       shaunking          1106448               1.0
# 418456    Laura_Kramer             2092               1.0
# 422268     ksmitty1812              298               1.0
# 415204  TwitterMoments           661418               1.0
# 133577  ShawnReynolds_            16637               1.0
# 121165    dismisstrump              727               1.0
# 411024    JimmyStreich             9198               1.0
#
#                                                 main_text  \
# 462059  Exclusive: Tucker Carlson's sexual comments ab...
# 423488  Tucker Carlson on then 17 year old Miss Teen U...
# 392143  Republicans defend Tucker Carlson (who jokes a...
# 406792  RT @joncoopertweets: Tucker Carlson's sexual c...
# ...

# %%
## Trump MAGA base, far right PRO

df_com_2_top_20.head(10)
# Out:
#           screen_name  followers_count  modularity_class  \
# 327441   RealCandaceO          1145530               2.0
# 85800        SebGorka           734318               2.0
# 262461       MarkDice           417310               2.0
# 55713   heyitsCarolyn            54860               2.0
# 144717    Vicky4Trump            66484               2.0
# 94891   1776Stonewall           200529               2.0
# 416902  marklevinshow          1524646               2.0
# 83870   AnthemRespect            81671               2.0
# 114102  BreitbartNews          1071855               2.0
# 335425  SheriffClarke           957326               2.0
#
#                                                 main_text  \
# 327441  The attacks on @JudgeJeanine &amp; @TuckerCarl...
# 85800   RT @SebGorka: They are out to destroy @JudgeJe...
# 262461  RT @SteveKrak: The guy leading the Media Matte...
# 55713   RT @heyitsCarolyn: It seems to me that the goa...
# ...

# %%
## Very similar to 2 PRO
df_com_3_top_20.head(10)
# Out:
#            screen_name  followers_count  modularity_class  \
# 368546    PrisonPlanet           937716               3.0
# 397109       SteveKrak            19046               3.0
# 292831    RealSaavedra           197790               3.0
# 379397     RubinReport           542851               3.0
# 359758     DailyCaller           482726               3.0
# 294552    JackPosobiec           438498               3.0
# 453202      benshapiro          2016170               3.0
# 226917       Cernovich           451166               3.0
# 298709  ArthurSchwartz            50761               3.0
# 10299        ZubyMusic            37567               3.0
#
#                                                 main_text  \
# 368546  RT @PrisonPlanet: Retweet if you couldn't give...
# 397109  The guy leading the Media Matters campaign aga...
# 292831  RT @RealSaavedra: Tucker Carlson highlights th...
# 379397  This mutually assured destruction is exactly w...
# ...

# %%
## LIBS, media ANTI
df_com_4_top_20.head(10)
# Out:
#             screen_name  followers_count  modularity_class  \
# 91178   FullFrontalSamB           563502               4.0
# 64252       BettyBowers           215321               4.0
# 420493    MollyJongFast           207843               4.0
# 53647       andylassner           362993               4.0
# 46597      thekjohnston            57563               4.0
# 113098     davidzurawik            12854               4.0
# 430823        readfearn             8397               4.0
# 242589       mikeymusto            19060               4.0
# 379895  Trumptweets2020            41318               4.0
# 507203      hopewell711              726               4.0
#
#                                                 main_text  \
# 91178   ICYMI: We're not saying Tucker Carlson is a wh...
# 64252   Tucker Carlson &amp; Trump are lying:\n\n1.  T...
# 420493  RT @nowthisnews: Exclusive: Tucker Carlson's s...
# 53647   A fabulous piece by the glamorous @MollyJongFa...
# ...

# %%
## leftists, activists ANTI

df_com_5_top_20.head(10)
# Out:
#             screen_name  followers_count  modularity_class  \
# 402402    OhNoSheTwitnt           285478               5.0
# 196049   EmilyGorcenski            53469               5.0
# 501429          Remroum            47625               5.0
# 197014             DubJ             1025               5.0
# 193845  Error_Processor             1351               5.0
# 49088         katystoll            33959               5.0
# 42349      drmistercody            63683               5.0
# 202987        BriannaWu            84181               5.0
# 46579   JenAshleyWright            94364               5.0
# 174800   absurdistwords            49293               5.0
#
#                                                 main_text  \
# 402402  “Gender neutral public bathrooms are endangeri...
# 196049  We can stop sharing shitty takes from:\n\n- Be...
# 501429  RT @Remroum: "If you take down Tucker Carlson,...
# 197014  Of course Donald Trump is complicit.\nOf cours...
# ...

# %%
## weird - let's look back into this after topic modeling

df_com_6_top_20.head(10)
# Out:
#             screen_name  followers_count  modularity_class  \
# 193448  andrewdoyle_com            19168               6.0
# 272150     kittypurrzog            14585               6.0
# 315703           JWSpry             7712               6.0
# 184999   ThePeteRaymond            15432               6.0
# 46240      LumpyTheCook              144               6.0
# 387907          ENBrown            33448               6.0
# 293923   _TheCivilRight             9067               6.0
# 323871  FindalGriffiths              199               6.0
# 261026     NorthernPleb             3508               6.0
# 107877    StefMNicholas            15057               6.0
#
#                                                 main_text  \
# 193448  “Tucker Carlson is to blame” (@BriannaWu)\n\n“...
# 272150  Media Matters digs up old dirt on Tucker Carls...
# 315703  RT @JWSpry: HOW can you “save the planet” by u...
# 184999  RT @andrewdoyle_com: “Tucker Carlson is to bla...
# ...

# %%
## #Resistance twitter, krassenstein etc ANTI

df_com_7_top_20.head(10)
# Out:
#             screen_name  followers_count  modularity_class  \
# 416404  joncoopertweets           245938               7.0
# 133789     krassenstein           665893               7.0
# 503567      StephenKing          5172693               7.0
# 113450        EdKrassen           900280               7.0
# 434810    ProudResister           304515               7.0
# 468271        B52Malmet            88070               7.0
# 468011           mjfree           124592               7.0
# 493500   TheRickyDavila           299903               7.0
# 402444   TheChrisSuprun            13512               7.0
# 435009       WajahatAli           116391               7.0
#
#                                                 main_text  \
# 416404  RT @StephenKing: Next to “male chauvinist pig”...
# 133789  @realDonaldTrump @JudgeJeanine Tucker Carlson ...
# 503567  Next to “male chauvinist pig” in the dictionar...
# 113450  Taking Judge Jeanine off air is not enough for...
# ...

# %%
## Seems Pro but look at after doing topic modeling

df_com_8_top_20.head(10)
# Out:
#             screen_name  followers_count  modularity_class  \
# 5319      ColumbiaBugle           101036               8.0
# 487676     Partisangirl           107507               8.0
# 441558  StrikerIsNazbol             3046               8.0
# 224355         ramzpaul            48515               8.0
# 213625           rooshv            53498               8.0
# 471120        DerayJack             1212               8.0
# 438858          TOOEdit            29591               8.0
# 266707        wisermann             4288               8.0
# 469300   robert_mariani             4628               8.0
# 497210    IraqiSecurity            41747               8.0
#
#                                                 main_text  \
# 5319    RT @ColumbiaBugle: Tucker Carlson discussing i...
# 487676  If only as much vitriol was launched at Obama ...
# 441558  RT @MarkDice: Tucker Carlson just called Brian...
# 224355  RT @PrisonPlanet: Antifa is once again plannin...
# ...

# %%
## Black media, not sure, look at topic models

df_com_9_top_20.head(10)
# Out:
#           screen_name  followers_count  modularity_class  \
# 509434   tariqnasheed           238640               9.0
# 451853  BreakingBrown            16166               9.0
# 85877     TalbertSwan           101412               9.0
# 64186      Rashad1380             5920               9.0
# 499627    DrReneeObey             6267               9.0
# 190572    edmgail1944              746               9.0
# 299023   sprbrighting            14797               9.0
# 164088         JKealt              127               9.0
# 35239          dijoni             6097               9.0
# 381278  gondwetamara1             1183               9.0
#
#                                                 main_text  \
# 509434  More old audio clips reveal Tucker Carlson is ...
# 451853  Read a thread where some1 tried to connect #AD...
# 85877   This past weekend, Trump:\n\nTold FCC to inves...
# 64186   I'm open to having a national discussion that ...
# ...

# %%
## Conservatives (non famous outside twitter), Pro

df_com_10_top_20.head(10)
# Out:
#             screen_name  followers_count  modularity_class  \
# 296709  TheRightMelissa           168342              10.0
# 200605   sanddollar1313              897              10.0
# 119967  ShirleyRinguet5             6898              10.0
# 425756      TWEETNMAC74             3966              10.0
# 67913          BeeZired             4753              10.0
# 164480           cderbs              410              10.0
# 170899    NickyNegative              710              10.0
# 134533   carolinastreet               18              10.0
# 155373   alexascylarken              699              10.0
# 161177   SaveLiberty1st            12108              10.0
#
#                                                 main_text  \
# 296709  RT @RealCandaceO: The attacks on @JudgeJeanine...
# 200605  RT @WayneDupreeShow: @TuckerCarlson Hey, how m...
# 119967  RT @RyanAFournier: Raise your hand if you stan...
# 425756  RT @beer_parade: @PrincessPatrio1 @TheyDontKno...
# ...

# %%
## Reporters, mainstream, ANTI

df_com_11_top_20.head(10)
# Out:
#            screen_name  followers_count  modularity_class  \
# 363079   JaneMayerNYer           193054              11.0
# 471292             CNN         41568504              11.0
# 237378         MaxBoot           220553              11.0
# 462545  washingtonpost         13498165              11.0
# 502254   JRubinBlogger           256326              11.0
# 477303           AC360          1282679              11.0
# 271266   thedailybeast          1211902              11.0
# 60070          RBReich           661241              11.0
# 399172         thehill          3221850              11.0
# 288703     emrosenberg             4504              11.0
#
#                                                 main_text  \
# 363079  Who Bankrolls Tucker Carlson's Hateful Propaga...
# 471292  "This is vulgarity. This is hate speech. This ...
# 237378  RT @MaxBoot: .@TuckerCarlson called Iraqis “se...
# 462545  Opinion: Tucker Carlson needs to go. Now. http...
# ...

# %%
## small time anti

df_com_12_top_20.head(10)
# Out:
#             screen_name  followers_count  modularity_class  \
# 98290      RoombaTucker              758              12.0
# 100911     Joe_Dameron8              223              12.0
# 101061    thezombiejose               22              12.0
# 483071     Mary38343030                9              12.0
# 100894       Alyssiadsp               17              12.0
# 101012   juanAKAdonjuan              367              12.0
# 100973          kande61                4              12.0
# 101001       Inreksalsa              331              12.0
# 100932  _garylasereyes_                3              12.0
# 92057         DellaLupi               88              12.0
#
#                                                 main_text  \
# 98290   For the record, yes, I am the one @TuckerCarls...
# 100911  I knew it @TuckerCarlson #TuckerCarlsonFucksHi...
# 101061  DJ Roomba did not deserve this @TuckerCarlson ...
# 483071  RT @JRubinBlogger: "high time for both adverti...
# ...
